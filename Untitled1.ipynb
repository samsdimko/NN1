# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import tensorflow as tf
import os
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
import pathlib
from pathlib import Path

data_root = Path("/media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images")

print(data_root)
# Out:
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images

# %%
for item in data_root.iterdir():
    print(item)
# Out:
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Georges_Seurat
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Edvard_Munch
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Marc_Chagall
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Andy_Warhol
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Salvador_Dali
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Hieronymus_Bosch
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Pablo_Picasso
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Andrei_Rublev
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Henri_Rousseau
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Paul_Gauguin
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/El_Greco
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Amedeo_Modigliani
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Gustav_Klimt
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Sandro_Botticelli
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Titian
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Vasiliy_Kandinskiy
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Francisco_Goya
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Caravaggio
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Frida_Kahlo
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Rembrandt
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Eugene_Delacroix
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Diego_Rivera
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/William_Turner
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Edgar_Degas
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Rene_Magritte
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Kazimir_Malevich
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Joan_Miro
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Pieter_Bruegel
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Claude_Monet
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Jackson_Pollock
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Paul_Cezanne
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Gustave_Courbet
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Henri_Matisse
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Camille_Pissarro
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Edouard_Manet
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Henri_de_Toulouse-Lautrec
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Paul_Klee
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Vincent_van_Gogh
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Leonardo_da_Vinci
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Michelangelo
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Mikhail_Vrubel
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Piet_Mondrian
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Jan_van_Eyck
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Peter_Paul_Rubens
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Albrecht_Dürer
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Pierre-Auguste_Renoir
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Diego_Velazquez
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Giotto_di_Bondone
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Raphael
# /media/dmitry/4fe10f4c-fb9e-4f6c-870b-18e4796d5d8b/images/images/Alfred_Sisley

# %%
import random
all_image_paths = list(data_root.glob('*/*'))
all_image_paths = [str(path) for path in all_image_paths]
random.shuffle(all_image_paths)

image_count = len(all_image_paths)
image_count
# Out:
# 8446

# %%
import os
attributions = (data_root)
attributions = [line.split(' CC-BY') for line in attributions]
attributions = dict(attributions)


import IPython.display as display
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-15c87948ee75> in <module>
#       1 import os
#       2 attributions = (data_root)
# ----> 3 attributions = [line.split(' CC-BY') for line in attributions]
#       4 attributions = dict(attributions)
#       5
#
# TypeError: 'PosixPath' object is not iterable

# %%
for n in range(3):
    image_path = random.choice(all_image_paths)
    display.display(display.Image(image_path))
    print(caption_image(image_path))
    print()

# %%
label_names = sorted(item.name for item in data_root.glob('*/') if item.is_dir())
label_to_index = dict((name, index) for index, name in enumerate(label_names))
label_to_index
# Out:
# {'Albrecht_Dürer': 0,
#  'Alfred_Sisley': 1,
#  'Amedeo_Modigliani': 2,
#  'Andrei_Rublev': 3,
#  'Andy_Warhol': 4,
#  'Camille_Pissarro': 5,
#  'Caravaggio': 6,
#  'Claude_Monet': 7,
#  'Diego_Rivera': 8,
#  'Diego_Velazquez': 9,
#  'Edgar_Degas': 10,
#  'Edouard_Manet': 11,
#  'Edvard_Munch': 12,
#  'El_Greco': 13,
#  'Eugene_Delacroix': 14,
#  'Francisco_Goya': 15,
#  'Frida_Kahlo': 16,
#  'Georges_Seurat': 17,
#  'Giotto_di_Bondone': 18,
#  'Gustav_Klimt': 19,
#  'Gustave_Courbet': 20,
#  'Henri_Matisse': 21,
#  'Henri_Rousseau': 22,
#  'Henri_de_Toulouse-Lautrec': 23,
#  'Hieronymus_Bosch': 24,
#  'Jackson_Pollock': 25,
#  'Jan_van_Eyck': 26,
#  'Joan_Miro': 27,
#  'Kazimir_Malevich': 28,
#  'Leonardo_da_Vinci': 29,
#  'Marc_Chagall': 30,
#  'Michelangelo': 31,
#  'Mikhail_Vrubel': 32,
#  'Pablo_Picasso': 33,
#  'Paul_Cezanne': 34,
#  'Paul_Gauguin': 35,
#  'Paul_Klee': 36,
#  'Peter_Paul_Rubens': 37,
#  'Pierre-Auguste_Renoir': 38,
#  'Piet_Mondrian': 39,
#  'Pieter_Bruegel': 40,
#  'Raphael': 41,
#  'Rembrandt': 42,
#  'Rene_Magritte': 43,
#  'Salvador_Dali': 44,
#  'Sandro_Botticelli': 45,
#  'Titian': 46,
#  'Vasiliy_Kandinskiy': 47,
#  'Vincent_van_Gogh': 48,
#  'William_Turner': 49}

# %%
all_image_labels = [label_to_index[pathlib.Path(path).parent.name]
                    for path in all_image_paths]

print("First 10 labels indices: ", all_image_labels[:10])
# Out:
# First 10 labels indices:  [38, 39, 2, 0, 35, 24, 48, 21, 33, 33]

# %%
img_path = all_image_paths[0]
img_path
img_raw = tf.io.read_file(img_path)
print(repr(img_raw)[:100]+"...")
# Out:
# <tf.Tensor: id=1, shape=(), dtype=string, numpy=b'\xff\xd8\xff\xdb\x00C\x00\n\x07\x07\t\x07\x03\n\t\...

# %%
img_tensor = tf.image.decode_image(img_raw)

print(img_tensor.shape)
print(img_tensor.dtype)
# Out:
# (1077, 994, 3)
# <dtype: 'uint8'>

# %%
img_final = tf.image.resize(img_tensor, [500, 500])
img_final = img_final/255.0
print(img_final.shape)
print(img_final.numpy().min())
print(img_final.numpy().max())
# Out:
# (500, 500, 3)
# 0.0
# 0.9988711

# %%
def preprocess_image(image):
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [192, 192])
    image /= 255.0  # normalize to [0,1] range

    return image

# %%
def load_and_preprocess_image(path):
    image = tf.io.read_file(path)
    return preprocess_image(image)

# %%
import matplotlib.pyplot as plt

image_path = all_image_paths[0]
label = all_image_labels[0]

plt.imshow(load_and_preprocess_image(img_path))
plt.grid(False)
plt.xlabel(img_path)
plt.title(label_names[label].title())
print()

# %%
path_ds = tf.data.Dataset.from_tensor_slices(all_image_paths)
print(path_ds)
# Out:
# <TensorSliceDataset shapes: (), types: tf.string>

# %%
image_ds = path_ds.map(load_and_preprocess_image, num_parallel_calls=AUTOTUNE)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))
for n, image in enumerate(image_ds.take(4)):
    plt.subplot(2,2,n+1)
    plt.imshow(image)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    plt.xlabel(all_image_paths[n])
    plt.show()

# %%
label_ds = tf.data.Dataset.from_tensor_slices(tf.cast(all_image_labels, tf.int64))

for label in label_ds.take(10):
    print(label_names[label.numpy()])
# Out:
# Pierre-Auguste_Renoir
# Piet_Mondrian
# Amedeo_Modigliani
# Albrecht_Dürer
# Paul_Gauguin
# Hieronymus_Bosch
# Vincent_van_Gogh
# Henri_Matisse
# Pablo_Picasso
# Pablo_Picasso

# %%
image_label_ds = tf.data.Dataset.zip((image_ds, label_ds))
print(image_label_ds)
# Out:
# <ZipDataset shapes: ((192, 192, 3), ()), types: (tf.float32, tf.int64)>

# %%
ds = tf.data.Dataset.from_tensor_slices((all_image_paths, all_image_labels))

# Кортежи распаковываются в позиционные аргументы отображаемой функции
def load_and_preprocess_from_path_label(path, label):
    return load_and_preprocess_image(path), label

image_label_ds = ds.map(load_and_preprocess_from_path_label)
image_label_ds
# Out:
# <MapDataset shapes: ((192, 192, 3), ()), types: (tf.float32, tf.int32)>

# %%
BATCH_SIZE = 32


ds = image_label_ds.shuffle(buffer_size=image_count)
ds = ds.repeat()
ds = ds.batch(BATCH_SIZE)
ds = ds.prefetch(buffer_size=AUTOTUNE)
ds
# Out:
# <PrefetchDataset shapes: ((None, 192, 192, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
ds = image_label_ds.apply(tf.data.experimental.shuffle_and_repeat(buffer_size=image_count))
ds = ds.batch(BATCH_SIZE)
ds = ds.prefetch(buffer_size=AUTOTUNE)
ds
# Out:
# WARNING:tensorflow:From <ipython-input-21-4ce324d17dad>:1: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# <PrefetchDataset shapes: ((None, 192, 192, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
mobile_net = tf.keras.applications.MobileNetV2(input_shape=(192, 192, 3), include_top=False)
mobile_net.trainable=False

# %%
def change_range(image,label):
    return 2*image-1, label

keras_ds = ds.map(change_range)

# %%
image_batch, label_batch = next(iter(keras_ds))

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

model = Sequential()
model.add(Conv2D(1024, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(128))
model.add(Activation("relu"))

model.add(Dense(128))
model.add(Activation("relu"))
model.add(Dense(13))
model.add(Activation("softmax"))
model.compile(loss="sparse_categorical_crossentropy",optimizer="adam",metrics=["accuracy"])

history = model.fit(ds, batch_size=32, epochs=40, validation_split=0.1)
